# %%
import os

file_path = "/kaggle/working/VITON-HD-main/train.py"
if os.path.exists(file_path):
    os.remove(file_path)
    print(f"{file_path} deleted successfully.")
else:
    print("File does not exist.")
# Out:
# /kaggle/working/VITON-HD-main/train.py deleted successfully.

# %%
import os

file_path = "/kaggle/working/VITON-HD-main/datasets.py"
if os.path.exists(file_path):
    os.remove(file_path)
    print(f"{file_path} deleted successfully.")
else:
    print("File does not exist.")

# %%
# !cp -r "/kaggle/input/datasets-update1/datasets.py" "/kaggle/working/VITON-HD-main"

# %%
# !cp -r "/kaggle/input/train-update6/train.py" "/kaggle/working/VITON-HD-main"

# %%
# !cp -r "/kaggle/input/viton-hd-new/VITON-HD-main-new/VITON-HD-main" "/kaggle/working/"

# %%
# !pip install kornia
# Out:
# ...
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7b5d1c5e4a90>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/nvidia-cuda-nvrtc-cu12/

# %%
# !python /kaggle/working/VITON-HD-main/train.py \
    --name vitonhd_optimized_run \
    --batch_size 1 \
    --dataset_dir /kaggle/input/clothes-tryon-dataset/clothes_tryon_dataset/ \
    --seg_checkpoint /kaggle/input/seg-epoch9/vitonhd_optimized_run_seg_epoch_9.pth \
    --gmm_checkpoint /kaggle/working/VITON-HD-main/checkpoints/gmm_final.pth \
    --alias_checkpoint /kaggle/input/alias-epoch9/vitonhd_optimized_run_alias_epoch_9.pth \
    --save_checkpoint_dir /kaggle/working/ \
    --epochs 30 \
    --max_steps 5000 \
    --lr 2e-5
# Out:
# ----------- Options -----------
# alias_checkpoint: /kaggle/input/alias-epoch9/vitonhd_optimized_run_alias_epoch_9.pth
# batch_size: 1
# dataset_dir: /kaggle/input/clothes-tryon-dataset/clothes_tryon_dataset/
# dataset_list: train_pairs.txt
# dataset_mode: train
# display_freq: 100
# epochs: 30
# gmm_checkpoint: /kaggle/working/VITON-HD-main/checkpoints/gmm_final.pth
# gpu_ids: 0
# grid_size: 5
# init_type: xavier
# init_variance: 0.02
# load_height: 1024
# load_width: 768
# lr: 2e-05
# max_steps: 5000
# name: vitonhd_optimized_run
# ngf: 64
# norm_G: spectralaliasinstance
# num_upsampling_layers: most
# save_checkpoint_dir: /kaggle/working/
# save_dir: /kaggle/working/visuals/
# seg_checkpoint: /kaggle/input/seg-epoch9/vitonhd_optimized_run_seg_epoch_9.pth
# semantic_nc: 13
# workers: 2
# -------------------------------
# Network [SegGenerator] was created. Total number of parameters: 34.5 million. To see the architecture, do print(network).
# ...
